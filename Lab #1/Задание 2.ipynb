# %% [markdown]
# # Лабараторная работа №1. Анализ данных в ГеймДеве.

# %% [markdown]
# ## Шаг 1

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

x = [3,21,22,34,54,34,55,67,89,99]
x = np.array(x)
y = [2,22,24,65,79,82,55,130,150,199]
y = np.array(y)

plt.scatter(x,y)

# %% [markdown]
# ## Шаг 2

# %%
def model(a, b, x):
    return a*x + b

def loss_function(a, b, x, y):
    num = len(x)
    prediction=model(a,b,x)
    return (0.5/num) * (np.square(prediction-y)).sum()

def optimize(a,b,x,y):
    num = len(x)
    prediction = model(a,b,x)
    da = (1.0/num) * ((prediction -y)*x).sum()
    db = (1.0/num) * ((prediction -y).sum())
    a = a - Lr*da
    b = b - Lr*db
    return a, b

def iterate(a,b,x,y,times):
    for i in range(times):
        a,b = optimize(a,b,x,y)
    return a,b

# %% [markdown]
# ## Шаг 3

# %% [markdown]
# ### Инициализация и модель оперативной оптимизации

# %%
a = np.random.rand(1)
print(a)
b = np.random.rand(1)
print(b)
Lr = 0.000001

a,b = iterate(a,b,x,y,1)
prediction=model(a,b,x)
loss = loss_function(a, b, x, y)
print(a,b,loss)
plt.scatter(x,y)
plt.plot(x,prediction)
# Out:
# [0.49275273]
# [0.13717863]
# [0.49670362] [0.13723574] 2659.3413871282887

# %% [markdown]
# ### Процесс обучения модели

# %%
a,b = iterate(a,b,x,y,2)
prediction=model(a,b,x)
loss = loss_function(a, b, x, y)
print(a,b,loss)
plt.scatter(x,y)
plt.plot(x,prediction)
# Out:
# [0.51238353] [0.13746229] 2597.9594939428375

# %%
a,b = iterate(a,b,x,y,3)
prediction=model(a,b,x)
loss = loss_function(a, b, x, y)
print(a,b,loss)
plt.scatter(x,y)
plt.plot(x,prediction)
# Out:
# [0.52401467] [0.13763025] 2552.926158483347

# %%
a,b = iterate(a,b,x,y,4)
prediction=model(a,b,x)
loss = loss_function(a, b, x, y)
print(a,b,loss)
plt.scatter(x,y)
plt.plot(x,prediction)
# Out:
# [0.5393531] [0.1378516] 2494.188659591146

# %%
a,b = iterate(a,b,x,y,5)
prediction=model(a,b,x)
loss = loss_function(a, b, x, y)
print(a,b,loss)
plt.scatter(x,y)
plt.plot(x,prediction)
# Out:
# [0.55825674] [0.13812419] 2422.8150969529142

# %%
a,b = iterate(a,b,x,y,6)
prediction=model(a,b,x)
loss = loss_function(a, b, x, y)
print(a,b,loss)
plt.scatter(x,y)
plt.plot(x,prediction)
# Out:
# [0.58055215] [0.13844538] 2340.0780820339714

# %% [markdown]
# ### Модель обучена

# %%
a,b = iterate(a,b,x,y,10000)
prediction=model(a,b,x)
loss = loss_function(a, b, x, y)
print(a,b,loss)
plt.scatter(x,y)
plt.plot(x,prediction)
# Out:
# [1.75123804] [0.12587045] 189.13293901937362

# %%
## УРА ОНО ОБУЧИЛОСЬ
